# %% [markdown]
# ## IBM Data Science Capstone Project
#
# This notebook is created to complete the final capstone project on IBM Data Science Specialization course on Coursera.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
